# %%
import pandas as pd
from util import *
import plotly.io as pio


pio.templates.default = "plotly_dark"

# %% [markdown]
# # Progress Data TPS

# %%
import plotly.express as px

# %%
df = pd.read_csv('dataset/progress.csv')

# %%
pd.set_option('display.max_colwidth', None)
pd.options.plotting.backend = "plotly"

# %%
Y = [it for it in filter(lambda x: x != 'dataset', df.columns)]

# %%
for y in Y:
    df.plot(x='dataset', y=y).show()
