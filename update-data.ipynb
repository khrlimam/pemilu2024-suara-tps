# %%
import pandas as pd
from util import *
# Out:
# /Users/khairulimam/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
pd.set_option('display.max_colwidth', None)

# %%
dfp = pd.read_csv('dataset/suara-tps.csv', low_memory=False)

# %%
dfn = pd.read_csv('berlebih-21-02/suara-tps.csv')

# %%
add_web_page(dfn)

# %%
add_provinsi(dfn)

# %%
updted_dfp = update(dfp, dfn)

# %%
updted_dfp.to_csv('normalized/21-02-2024.csv', index=False)

# %%
normalized = dfn[dfn['suara_paslon-suara_sah'] == 0]

# %%
normalized
# Out:
#                 tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 0     3515152012005        33       161        23                 217
# 10    3516112002013        21       186        35                 242
# 19    1114082014002         0         0         0                   0
# 22    3202452004002        46        93        18                 157
# 40    7501222003010        88       142        11                 241
# ...             ...       ...       ...       ...                 ...
# 5907  7171071005002         7       140        31                 178
# 5915  1702162005003        31       162        18                 211
# 5916  1703112001003        18       229         9                 256
# 5917  1703082003006        11       133        73                 217
# 5932  1705062008004        12       146        35                 193
#
#       suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# ...

# %%
normalized_anomali = normalized[normalized['total_suara_paslon'] == 0].loc[normalized['img2'] == '-']

# %%
normalized_anomali
# Out:
#                 tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 19    1114082014002         0         0         0                   0
# 54    3171081002071         0         0         0                   0
# 61    3518112010023         0         0         0                   0
# 121   6209062002005         0         0         0                   0
# 176   3518112008015         0         0         0                   0
# ...             ...       ...       ...       ...                 ...
# 5772  1671041001002         0         0         0                   0
# 5797  1671101004068         0         0         0                   0
# 5863  1209201009011         0         0         0                   0
# 5900  7102232006010         0         0         0                   0
# 5902  7102161003004         0         0         0                   0
#
#       suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# ...

# %%
normalized_o = dfp[dfp['tps'].isin(normalized_anomali.tps)]

# %%
# Out:
# Empty DataFrame
# Columns: [tps, paslon01, paslon02, paslon03, total_suara_paslon, suara_sah, suara_paslon-suara_sah, suara_tidak_sah, total_suara, img1, img2, img3, url_webpge, kode_provinsi, nama_provinsi]
# Index: []

# %%
find_by_tps(normalized_anomali, 3201362002014)
# Out:
#                tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 303  3201362002014         0         0         0                   0
#
#      suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara img1  \
# 303          0                       0                0            0    -
#
#     img2 img3  \
# 303    -    -
#
#                                                                                     url_webpge
# 303  https://pemilu2024.kpu.go.id/pilpres/hitung-suara/32/3201/320136/3201362002/3201362002014

# %%
normalized_o[normalized_o['img2'] == '-']
# Out:
#                   tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 817593  3201362002014         0         0         0                   0
# 818582  7309112005003         0         0         0                   0
# 818598  7309112006002         0         0         0                   0
# 818729  3512122002003         0         0         0                   0
# 818843  3515072019005         0         0         0                   0
# 818940  1108082030001         0         0         0                   0
# 818952  3515072011016         0         0         0                   0
# 819040  1905011001011         0         0         0                   0
# 819042  3519122010007         0         0         0                   0
# 819125  3506042012003         0         0         0                   0
# 819235  3513062002001         0         0         0                   0
# 819342  3510232001006         0         0         0                   0
# ...

# %%
dfp_o = dfp[dfp['tps'].isin(normalized.tps)]

# %%
dfpo_berlebih = dfp_o[dfp_o['suara_paslon-suara_sah'] > 0]

# %%
dfpo_berlebih
# Out:
#                   tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 817316  1114082014002       444        14         5                 463
# 817342  1509072004001        27       177        37                 241
# 817354  3171081002071       250       211       311                 772
# 817361  3518112010023       271       211       511                 993
# 817380  3506171009027        25       166        60                 251
# ...               ...       ...       ...       ...                 ...
# 823101  1603032004003       423       144       427                 994
# 823152  1209201009011       107       777         5                 889
# 823195  7102232006010       826       225        14                1065
# 823199  7102161003004       190         1       191                 382
# 823230  1705062008004         2       146       257                 405
#
#         suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# ...

# %% [markdown]
# ### Jumlah Data Berlebih Yang Sudah Diperbaiki

# %%
dfn[dfn['suara_paslon-suara_sah'] == 0]
# Out:
#                 tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 0     3515152012005        33       161        23                 217
# 10    3516112002013        21       186        35                 242
# 19    1114082014002         0         0         0                   0
# 22    3202452004002        46        93        18                 157
# 40    7501222003010        88       142        11                 241
# ...             ...       ...       ...       ...                 ...
# 5907  7171071005002         7       140        31                 178
# 5915  1702162005003        31       162        18                 211
# 5916  1703112001003        18       229         9                 256
# 5917  1703082003006        11       133        73                 217
# 5932  1705062008004        12       146        35                 193
#
#       suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# ...

# %%
find_by_tps(dfp_o, 1114082014002)
# Out:
#                   tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 817316  1114082014002       444        14         5                 463
#
#         suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# 817316        163                     300                5          168
#
#                                                      img1  \
# 817316  https://sirekap-obj-formc.kpu.go.id/f4f3/pemil...
#
#                                                      img2  \
# 817316  https://sirekap-obj-formc.kpu.go.id/f4f3/pemil...
#
#                                                      img3  \
# 817316  https://sirekap-obj-formc.kpu.go.id/f4f3/pemil...
#
#                                                url_webpge  kode_provinsi  \
# 817316  https://pemilu2024.kpu.go.id/pilpres/hitung-su...             11
#
#        nama_provinsi
# 817316          ACEH

# %%
normalized[(normalized['total_suara_paslon'] == 0) & (normalized['suara_sah'] > 0)]
# Out:
#                 tps  paslon01  paslon02  paslon03  total_suara_paslon  \
# 19    1114082014002         0         0         0                   0
# 54    3171081002071         0         0         0                   0
# 61    3518112010023         0         0         0                   0
# 63    3174071009028         0         0         0                   0
# 121   6209062002005         0         0         0                   0
# ...             ...       ...       ...       ...                 ...
# 5771  1671041006060         0         0         0                   0
# 5772  1671041001002         0         0         0                   0
# 5863  1209201009011         0         0         0                   0
# 5900  7102232006010         0         0         0                   0
# 5902  7102161003004         0         0         0                   0
#
#       suara_sah  suara_paslon-suara_sah  suara_tidak_sah  total_suara  \
# ...
